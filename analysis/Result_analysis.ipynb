# %%
import matplotlib.pyplot as plt
import numpy as np

# Data organized by model and metric for easier plotting
data = {
    '1hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.9929, 0.9879, 0.989, 0.997],
        'WAPE': [3.342, 4.66, 8.75, 1.252]
    },
    '3hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.941, 0.934, 0.967, 0.942],
        'WAPE': [9.62, 10.68, 14.635, 6.27]
    },
    '6hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.813, 0.817, 0.927, 0.793],
        'WAPE': [18.27, 18.73, 21.632, 12.6]
    },
    '12hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.598, 0.617, 0.8435, 0.533],
        'WAPE': [27.08, 27.25, 31.83, 19.3]
    },
    '24hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.411, 0.4355, 0.7086, 0.361],
        'WAPE': [30.53, 31.26, 43.24, 27.63]
    }
}

# Plotting
fig, axes = plt.subplots(2, 2, figsize=(15, 10), sharey='row')
fig.suptitle('Model Performance Comparison Across Different Time Horizons')

# Utility function for plotting bar graphs
def plot_bars(ax, data, title):
    x = np.arange(len(data['Models']))
    width = 0.35  # width of the bars
    
    ax.bar(x - width/2, data['NSE'], width, label='NSE')
    ax.bar(x + width/2, data['WAPE'], width, label='WAPE')
    
    ax.set_ylabel('Scores')
    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(data['Models'])
    ax.legend()

# Plot for each frequency
plot_bars(axes[0, 0], data['1hr'], '1 Hour Forecast')
plot_bars(axes[0, 1], data['3hr'], '3 Hour Forecast')
plot_bars(axes[1, 0], data['6hr'], '6 Hour Forecast')
plot_bars(axes[1, 1], data['12hr'], '12 Hour Forecast')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()


0.9929	,	0.941	,	0.813	,	0.598	,	0.411

# %%
x = '''
0.996	2.0	0.9897	3.13	0.977	4.72	0.952	6.788	0.921	8.873'''

y = '''
0.995	2.13	0.988	3.316	0.978	4.54	0.958	6.479	0.93	8.3'''

xt = [float(t.strip()) for t in y.split('\t')]
[xt[i] for i in range(len(xt)) if i%2==0]
# Out:
# [0.995, 0.988, 0.978, 0.958, 0.93]

# %%
import matplotlib.pyplot as plt
import numpy as np
# Data for plotting line graphs
# singal variate i.e. only gauge height
horizons = ['1hr', '3hr', '6hr', '12hr', '24hr']
nse_data = {
     'TiDE': [0.9929, 0.941, 0.813, 0.598, 0.411],
     'N-HiTS': [0.9879, 0.934, 0.817, 0.617, 0.4355],
     'PatchTST': [0.996, 0.9897, 0.977, 0.952, 0.921],
     'LSTM': [0.997, 0.942, 0.793, 0.533, 0.361]
    }

wape_data = {
     'TiDE': [3.342, 9.62, 18.27, 27.08, 30.53],
     'N-HiTS': [4.66, 10.68, 18.73, 27.25, 31.26],
     'PatchTST': [2.0, 3.13, 4.72, 6.788, 8.873],
     'LSTM': [1.252, 6.27, 12.6, 19.3, 27.63]
    }

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 14

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_xlabel('Forecast Horizon', fontsize=15)
axes[0].set_ylabel('NSE', fontsize=15)
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_xlabel('Forecast Horizon', fontsize=15)
axes[1].set_ylabel('WAPE', fontsize=15)
axes[1].legend()

plt.tight_layout()
plt.savefig(f'plot_results/24hr_vs_horizons.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Data for plotting line graphs
# singal variate i.e. only gauge height
horizons = ['1hr', '3hr', '6hr', '12hr', '24hr']
nse_data = {'TiDE': [0.978, 0.914, 0.789, 0.604, 0.4432],
 'N-HiTS': [0.974, 0.91, 0.79, 0.6, 0.4417],
 'PatchTST': [0.995, 0.988, 0.978, 0.958, 0.93],
 'LSTM': [0.996, 0.941, 0.783, 0.535, 0.39]}

wape_data = {'TiDE': [6.34, 12.486, 19.66, 26.62, 30.04],
 'N-HiTS': [6.78, 12.63, 19.82, 26.9, 30.3],
 'PatchTST': [2.13, 3.316, 4.54, 6.479, 8.3],
 'LSTM': [2.1, 9.89, 21.09, 32.148, 36.68]}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_xlabel('Forecast Horizon', fontsize=15)
axes[0].set_ylabel('NSE', fontsize=15)
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_xlabel('Forecast Horizon', fontsize=15)
axes[1].set_ylabel('WAPE', fontsize=15)
axes[1].legend()

plt.tight_layout()
plt.savefig(f'plot_results/96hr_vs_horizons.png', dpi=300)
plt.show()

# %%
# Data for plotting line graphs
# multi variate with season data and gauge height
horizons = ['1hr', '3hr', '6hr', '12hr']
nse_data = {
    'TiDE': [0.9861, 0.894, 0.7384, 0.5233],
    'N-HiTS': [0.9673, 0.8702, 0.7215, 0.539],
    'PatchTST': [0.9918, 0.9765, 0.9476, 0.9035],
}
wape_data = {
    'TiDE': [4.43, 13.91, 23.33, 30.95],
    'N-HiTS': [9.43, 17.46, 25.74, 31.69],
    'PatchTST': [4.36, 6.8, 11.05, 14.97],
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Model Performance Across Different Time Horizons for gauge height and season data')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Data for plotting line graphs
# multi variate with precipitation, season data and gauge height
horizons = ['1hr', '3hr', '6hr', '12hr']
nse_data = {
    'TiDE': [0.9873, 0.9001, 0.7583, 0.5513],
    'N-HiTS': [0.9623, 0.8752, 0.7419, 0.5628],
    'PatchTST': [0.7661, 0.7411, 0.713, 0.677],
}
wape_data = {
    'TiDE': [4.21, 13.47, 22.54, 30.28],
    'N-HiTS': [10.11, 17.03, 24.36, 30.24],
    'PatchTST': [9.5, 12.58, 15.17, 18.92],
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Model Performance Across Different Time Horizons for gauge height, Precip. and season data')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Data for plotting line graphs
# multi variate with precipitation and gauge height
horizons = ['1hr', '3hr', '6hr', '12hr']
nse_data = {
    'TiDE': [0.9857, 0.8972, 0.7485, 0.541],
    'N-HiTS': [0.9797, 0.8918, 0.7545, 0.5666],
    'PatchTST': [0.479, 0.4444, 0.3842, 0.3074],
}
wape_data = {
    'TiDE': [4.88, 14.13, 23.31, 30.86],
    'N-HiTS': [7.28, 15.69, 24.09, 30.91],
    'PatchTST': [27.99, 31.19, 41.41, 52.11],
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Model Performance Across Different Time Horizons for gauge height and Precip. data')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Data for plotting line graphs
# Plotting how a model performs when using differnt type of variates
horizons = ['1hr', '3hr', '6hr', '12hr']
nse_data = {
    'gauge height only': [0.9867, 0.8972, 0.7444, 0.5275],
    'gauge height and season': [0.9861, 0.894, 0.7384, 0.5233],
    'gauge height and precip.': [0.9857, 0.8972, 0.7485, 0.541],
    'gauge height, precip. and season': [0.9873, 0.9001, 0.7583, 0.5513]
}
wape_data = {
    'gauge height only': [4.63, 13.81, 23.04, 31.12],
    'gauge height and season': [4.43, 13.91, 23.33, 30.95],
    'gauge height and precip.': [4.88, 14.13, 23.31, 30.86],
    'gauge height, precip. and season': [4.21, 13.47, 22.54, 30.28]
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Performance of TiDE when using different data variables for training')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Data for plotting line graphs
# Plotting how a model performs when using differnt type of variates
horizons = ['1hr', '3hr', '6hr', '12hr']
nse_data = {
    'gauge height only': [0.9824, 0.8883, 0.7367, 0.5313],
    'gauge height and season': [0.9673, 0.8702, 0.7215, 0.539],
    'gauge height and precip.': [0.9797, 0.8918, 0.7545, 0.5666],
    'gauge height, precip. and season': [0.9623, 0.8752, 0.7419, 0.5628]
}
wape_data = {
    'gauge height only': [6.1, 15.03, 23.61, 30.79],
    'gauge height and season': [9.43, 17.46, 25.74, 31.69],
    'gauge height and precip.': [7.28, 15.69, 24.09, 30.91],
    'gauge height, precip. and season': [10.11, 17.03, 24.36, 30.24]
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Performance of N-HiTS when using different data variables for training')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Data for plotting line graphs
# Plotting how a model performs when using differnt type of variates
horizons = ['1hr', '3hr', '6hr', '12hr']
nse_data = {
    'gauge height only': [0.9818, 0.9248, 0.83, 0.6744],
    'gauge height and season': [0.9918, 0.9765, 0.9476, 0.9035],
    'gauge height and precip.': [0.479, 0.4444, 0.3842, 0.3074],
    'gauge height, precip. and season': [0.7661, 0.7411, 0.713, 0.677]
}
wape_data = {
    'gauge height only': [8.712, 18.83, 31.74, 46.58],
    'gauge height and season': [4.36, 6.8, 11.05, 14.97],
    'gauge height and precip.': [27.99, 31.19, 41.41, 52.11],
    'gauge height, precip. and season': [9.5, 12.58, 15.17, 18.92]
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Performance of PatchTST when using different data variables for training')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model)
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model)
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
a = 'abcded'
sorted(a)
# Out:
# ['a', 'b', 'c', 'd', 'd', 'e']

# %%
A={'A':1, 'B':2}
sum(A.values())
# Out:
# 3

# %%
sum(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sum(A)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
data = {
    '1hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.978, 0.974, 0.982, 0.996],
        'WAPE': [6.34, 6.78, 11.19, 2.1]
    },
    '3hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.914, 0.91, 0.9618, 0.941],
        'WAPE': [12.486, 12.63, 16.11, 9.89]
    },
    '6hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.789, 0.79, 0.9288, 0.783],
        'WAPE': [19.66, 19.82, 21.75, 21.09]
    },
    '12hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.604, 0.6, 0.856, 0.535],
        'WAPE': [26.62, 26.9, 31.443, 32.148]
    },
    '24hr': {
        'Models': ['TiDE', 'N-HiTS', 'PatchTST', 'LSTM'],
        'NSE': [0.4432, 0.4417, 0.74, 0.39],
        'WAPE': [30.04, 30.3, 41.65, 36.68]
    }
}


nse = {}
wape = {}

keys = data.keys()

# %%
keys
# Out:
# dict_keys(['1hr', '3hr', '6hr', '12hr', '24hr'])

# %%
models = data['1hr']['Models']

# %%
for model in models:
    nse[model] = []
    wape[model] = []

for hr in keys:
    for i, name in enumerate(data[hr]['Models']):
        nse[name].append(data[hr]['NSE'][i])
        wape[name].append(data[hr]['WAPE'][i])

# %%
nse
# Out:
# {'TiDE': [0.978, 0.914, 0.789, 0.604, 0.4432],
#  'N-HiTS': [0.974, 0.91, 0.79, 0.6, 0.4417],
#  'PatchTST': [0.982, 0.9618, 0.9288, 0.856, 0.74],
#  'LSTM': [0.996, 0.941, 0.783, 0.535, 0.39]}

# %%
wape
# Out:
# {'TiDE': [6.34, 12.486, 19.66, 26.62, 30.04],
#  'N-HiTS': [6.78, 12.63, 19.82, 26.9, 30.3],
#  'PatchTST': [11.19, 16.11, 21.75, 31.443, 41.65],
#  'LSTM': [2.1, 9.89, 21.09, 32.148, 36.68]}

# %%
# To Be Presented at IEMSS Conference

import matplotlib.pyplot as plt
import numpy as np

# Variables and their corresponding NSE and WAPE values for N-HiTS and LSTM
variables = ['Dry Bulb Temp.', 'Wet Bulb Temp.', 'Precipitation', 'Station Pressure', 'Relative Humidity', 'Wind Speed']
n_hits_nse = [ 0.9277, 0.9285, 0.9421, 0.9274, 0.92, 0.9288]
n_hits_wape = [ 11.1, 11.232, 9.82, 11.47, 11.47, 11.274]
lstm_nse = [ 0.894, 0.9184, 0.977, 0.878, 0.749, 0.585]
lstm_wape = [ 23.99, 13.62, 2.84, 15.76, 32.75, 23.56]

x = np.arange(len(variables))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(2, 1, figsize=(14, 12))

# NSE plot
ax[0].bar(x - width/2, n_hits_nse, width, label='N-HiTS', color='blue')
ax[0].bar(x + width/2, lstm_nse, width, label='LSTM', color='green')
ax[0].set_ylabel('NSE')
ax[0].set_title('NSE by Variable and Model')
ax[0].set_xticks(x)
ax[0].set_xticklabels(variables)
ax[0].legend()

# WAPE plot
ax[1].bar(x - width/2, n_hits_wape, width, label='N-HiTS', color='blue')
ax[1].bar(x + width/2, lstm_wape, width, label='LSTM', color='green')
ax[1].set_ylabel('WAPE')
ax[1].set_title('WAPE by Variable and Model')
ax[1].set_xticks(x)
ax[1].set_xticklabels(variables)
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
# Enhanced visualization focusing on subtle differences and highlighting key variables
fig, ax = plt.subplots(2, 1, figsize=(6, 7))

# Define colors for emphasis
colors_nhits = ['#006400' if var not in ['Wet Bulb Temp.', 'Precipitation'] else '#F56600' for var in variables]
colors_lstm = ['#006400' if var not in ['Wet Bulb Temp.', 'Precipitation'] else '#F56600' for var in variables]

# NSE plot with adjusted y-axis for better visibility
ax[0].bar(x - width/2, n_hits_nse, width, label='N-HiTS', color=colors_nhits)
ax[0].bar(x + width/2, lstm_nse, width, label='LSTM', color=colors_lstm)
ax[0].set_ylabel('NSE')
ax[0].set_title('NSE by Variable and Model (Focused Scale)')
ax[0].set_ylim(0.55, 1.2)  # Adjusting y-axis limits for better visibility of differences
ax[0].set_xticks(x)
ax[0].set_xticklabels(variables, rotation=45, ha="right")
ax[0].legend()

# WAPE plot with adjusted y-axis
ax[1].bar(x - width/2, n_hits_wape, width, label='N-HiTS', color=colors_nhits)
ax[1].bar(x + width/2, lstm_wape, width, label='LSTM', color=colors_lstm)
ax[1].set_ylabel('WAPE')
ax[1].set_title('WAPE by Variable and Model (Focused Scale)')
ax[1].set_ylim(0, 50)  # Adjusting y-axis limits for better visibility of differences
ax[1].set_xticks(x)
ax[1].set_xticklabels(variables, rotation=45, ha="right")
ax[1].legend()

plt.tight_layout()
plt.savefig('plot_results/nse_wape_bar_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Data for plotting line graphs
# singal variate i.e. only gauge height
horizons = ['1hr', '3hr', '6hr', '12hr', '24hr']
nse_data = {
     'N-HiTS': [0.9879, 0.934, 0.817, 0.617, 0.4355],
     'LSTM': [0.997, 0.942, 0.793, 0.533, 0.361]
    }

wape_data = {
     'N-HiTS': [4.66, 10.68, 18.73, 27.25, 31.26],
     'LSTM': [1.252, 6.27, 12.6, 19.3, 27.63]
    }

gren = '#006400'
ornge = '#F56600'
colors = {'N-HiTS': gren, 'LSTM': ornge}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(10, 3.6))
fig.suptitle('Model Performance Across Different Forecast Horizons for lookback window of 24 hr')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model, color=colors[model])
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model, color=colors[model])
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.savefig('plot_results/horizons_window_24hr.png', dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Data for plotting line graphs
# singal variate i.e. only gauge height
horizons = ['1hr', '3hr', '6hr', '12hr', '24hr']
nse_data = {
 'N-HiTS': [0.974, 0.91, 0.79, 0.6, 0.4417],
 'LSTM': [0.996, 0.941, 0.783, 0.535, 0.39]
}

wape_data = {
 'N-HiTS': [6.78, 12.63, 19.82, 26.9, 30.3],
 'LSTM': [2.1, 9.89, 21.09, 32.148, 36.68]
}

# Create line plots
fig, axes = plt.subplots(1, 2, figsize=(10, 3.6))
fig.suptitle('Model Performance Across Different Forecast Horizons for lookback window of 96 hr')

# Plotting NSE
for model, values in nse_data.items():
    axes[0].plot(horizons, values, marker='o', label=model, color=colors[model])
axes[0].set_title('NSE by Forecast Horizon')
axes[0].set_xlabel('Forecast Horizon')
axes[0].set_ylabel('NSE')
axes[0].legend()

# Plotting WAPE
for model, values in wape_data.items():
    axes[1].plot(horizons, values, marker='o', label=model, color=colors[model])
axes[1].set_title('WAPE by Forecast Horizon')
axes[1].set_xlabel('Forecast Horizon')
axes[1].set_ylabel('WAPE')
axes[1].legend()

plt.tight_layout()
plt.savefig('plot_results/horizons_window_96hr.png', dpi=300)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define window sizes and corresponding metrics for each model
window_sizes = [6, 13, 18, 24, 48, 96]
gren = '#006400'
ornge = '#F56600'
blu = '#0064ff'
pur = '#800080'
# NHiTS Metrics
nhits_nse = np.array([0.9405, 0.9433, 0.9432, 0.9468, 0.9468, 0.941])
nhits_wape = np.array([9.32, 9.71, 9.43, 9.44, 9.607, 9.69])

# LSTM Metrics
lstm_nse = np.array([0.9157, 0.9402, 0.928, 0.92, 0.92, 0.9143])
lstm_wape = np.array([14.16, 12.72, 13.764, 13.5, 13.29, 14.25])

#TIDE Metrics
tide_nse = np.array([0.947, 0.948, 0.950, 0.949, 0.939, 0.9412])
tide_wape = np.array([8.814, 8.59, 8.624, 8.73, 9.884, 9.84])

#PatchTST Metrics
patchtst_nse = np.array([0.986, 0.987, 0.988, 0.989, 0.989, 0.990])
patchtst_wape = np.array([3.47, 3.37, 3.34, 3.13, 3.24, 3.21])

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 14  # Increase base font size

# Plotting function
def plot_metrics(window_sizes, nhits_metrics, lstm_metrics, tide_metrics, patchtst_metrics, metric_name, ylabel):
    plt.figure(figsize=(10, 4.5))
    plt.plot(window_sizes, nhits_metrics, marker='o', linestyle='-', color=gren, label='N-HiTS')
    plt.plot(window_sizes, lstm_metrics, marker='s', linestyle='--', color=ornge, label='LSTM')
    plt.plot(window_sizes, tide_metrics, marker='o', linestyle='-', color=blu, label='TiDE')
    plt.plot(window_sizes, patchtst_metrics, marker='s', linestyle='--', color=pur, label='PatchTST')
    #plt.title(f'{metric_name} Comparison for N-HiTS, LSTM, TiDE and PatchTST Across Window Sizes')
    plt.xlabel('Window Size (hours)')
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.xticks(window_sizes)
    plt.legend(bbox_to_anchor=(0.6,0.5))
    #plt.show()
    plt.savefig(f'plot_results/{ylabel}.png', dpi=300)

# Plot NSE
plot_metrics(window_sizes, nhits_nse, lstm_nse, tide_nse, patchtst_nse, 'NSE', 'NSE')

# Plot WAPE
plot_metrics(window_sizes, nhits_wape, lstm_wape, tide_wape, patchtst_wape, 'WAPE', 'WAPE')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data setup
data = {
    "Feature": ["None", "Dry Bulb Temp", "Wet Bulb Temp", "Precipitation", "Relative Humidity", "Wind Speed", "Air Pressure"],
    "PatchTST_WAPE": [8.72, 9.81, 10.54, 8.53, 7.7, 5.76, 10.29],
    "LSTM_WAPE": [5.73, 6.037, 6.36, 6.43, 6.23, 5.93, 5.9],
    "N-HiTS_WAPE": [12.023, 10.8, 10.74, 11.01, 11.34, 11.29, 10.85],
    "TiDE_WAPE": [8.674, 8.54, 8.51, 8.98, 8.91, 8.68, 8.79]
}
df = pd.DataFrame(data)
df.set_index("Feature", inplace=True)

# Set style and font parameters
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 14,
    'axes.labelsize': 12,
    'axes.titlesize': 18,
    'xtick.labelsize': 13,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 20
})

# Define a more attractive color palette
gren = '#006400'
ornge = '#F56600'
blu = '#0064ff'
pur = '#800080'
palette = [gren, ornge, blu, pur]

# Plotting
fig, ax = plt.subplots(figsize=(10, 5))
models = df.columns

for model, color in zip(models, palette):
    ax.plot(df.index, df[model], marker='o', linestyle='-', label=model.split('_')[0], linewidth=1, markersize=6, color=color)

ax.set_ylabel('WAPE', fontsize=16)
ax.set_xlabel('Excluded feature')
ax.legend(title="Model", title_fontsize='14', fontsize='12')

plt.xticks(rotation=15)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.savefig('plot_results/sensitivity_wape.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# Sample data setup
data = {
    "Feature": ["None", "Dry Bulb Temp.", "Wet Bulb Temp.", "Precipitation", "Relative Humidity", "Wind Speed", "Air Pressure"],
    "PatchTST_NSE": [0.955, 0.953, 0.947, 0.937, 0.974, 0.967, 0.953],
    "LSTM_NSE": [0.955, 0.953, 0.949, 0.94, 0.952, 0.949, 0.954],
    "N-HiTS_NSE": [0.916, 0.9316, 0.933, 0.9323, 0.933, 0.9316, 0.9355],
    "TiDE_NSE": [0.948, 0.948, 0.948, 0.946, 0.948, 0.948, 0.947]
}
df = pd.DataFrame(data)
df.set_index("Feature", inplace=True)

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 16  # Increase base font size
# Set style and font parameters
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 14,
    'axes.labelsize': 13,
    'axes.titlesize': 18,
    'xtick.labelsize': 13,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 20
})

# Define a more attractive color palette
gren = '#006400'
ornge = '#F56600'
blu = '#0064ff'
pur = '#800080'
palette = [gren, ornge, blu, pur]

# Plotting
fig, ax = plt.subplots(figsize=(10, 5))
models = df.columns

for model, color in zip(models, palette):
    ax.plot(df.index, df[model], marker='o', linestyle='-', label=model.split('_')[0], linewidth=1, markersize=6, color=color)

ax.set_ylabel('NSE', fontsize=16)
ax.set_xlabel('Excluded feature')
ax.set_title('')
ax.legend(title="Model")

plt.xticks(rotation=15)
plt.tight_layout()
plt.savefig(f'plot_results/sensitivity_nse.png', dpi=300)
plt.show()

# %%
import matplotlib
patchtst = '''

38807	3.863
61808	4.1316
90897	4.63369
126458	5.1026
168875	5.3744
218532	5.9717
275813	6.3545
341102	6.8257
414783	7.1114
497240	7.5927
588857	8.0438
690018	8.5358
801107	9.0778
922508	9.3085
1054605	9.8443
1722765	12.834
2176743	16.39
3597428	23.42
5464713	31.57
7826598	42.44
10731083  52.83
'''

nhits = '''
10707	5.19
37779	4.95
81235	4.89
141075	5
285491	5.29
429395	5.677
659603	5.787
938963	6.037
1410947	6.525
1904131	6.64
2471043	7.18
4834947	9.14
6448819	9.89
8607475	11.413
12809971	13.228
17012467	15.096
'''

tide = '''
49630	11.29
98654	12.028
320990	12.165
543326	12.405
765662	12.576
987998	13.18
1210334	13.07
2137822	13.346
2532574	13.542
3943774	14.18
4560094	15.285
5176414	14.955
7440350	16.218
8327390	16.207
9214430	17.546
10101470	18.12
13734622	19.52
14941534	19.72
16148446	21.443
'''

lstm = '''
67201	7.9055
149953	8.166
265473	8.679
413761	8.621
594817	9.092
808641	9.587
1055233	9.869
50497	7.823
199297	8.2258
446401	9.128
791809	9.568
1235521	10.335
1777537	11.128
2417857	12.248
2879041	13.15
3700801	14.91
4522561	16.18
6508417	18.29
7691137	20.348
8873857	22.83
10056577	24.7
13682369	32.24
'''


def parseTxt(txt):
    lines = txt.split('\n')
    params = []
    time = []
    for line in lines:
        if line:
            p, t = line.split()
            params.append(int(p))
            time.append(float(t))
    return params, time

params_1, times_1 = parseTxt(patchtst)
params_2, times_2 = parseTxt(nhits)
params_3, times_3 = parseTxt(tide)
params_4, times_4 = parseTxt(lstm)

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

gren = '#006400'
ornge = '#F56600'
blu = '#0064ff'
pur = '#800080'

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 14  # Increase base font size

# Plotting
plt.figure(figsize=(12, 7))
plt.plot(params_1, times_1, label='PatchTST (Transformer)', color=gren)
plt.plot(params_2, times_2, label='N-HiTS (Hierarchical MLP)', color=blu)
plt.plot(params_3, times_3, label='TiDE (Encoder-Decoder MLP)', color=pur)
plt.plot(params_4, times_4, label='LSTM (RNN)', color=ornge)

# Adding titles and labels
plt.xlabel('Number of Parameters (millions)')
plt.ylabel('Training time for epoch (seconds)')

# Set x-axis formatter to show values in terms of millions
formatter = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x * 1e-6))
plt.gca().xaxis.set_major_formatter(formatter)

plt.legend()
plt.grid(True)

# Show the plot
plt.savefig(f'plot_results/complexity.png', dpi=300)
plt.show()

# %%
a = '''
8.72
9.81
10.54
8.53
7.7
5.76
10.29
'''
[float(x) for x in a.split('\n') if x != '']
# Out:
# [8.72, 9.81, 10.54, 8.53, 7.7, 5.76, 10.29]

# %%
x = '''
0.986	3.47	0.987	3.37	0.988	3.34	0.989	3.13	0.989	3.24 '''
xt = [float(t.strip()) for t in x.split('\t')]
#[float(t) for t in x.split(' ')]

# %%
[xt[i] for i in range(len(xt)) if i%2==0]
# Out:
# [0.986, 0.987, 0.988, 0.989, 0.989]

# %%
[xt[i] for i in range(len(xt)) if i%2!=0]
# Out:
# [3.47, 3.37, 3.34, 3.13, 3.24]
